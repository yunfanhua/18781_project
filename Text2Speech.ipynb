# %% [markdown]
# # 1. Install necessary package
# 1. espnet(need installation: pip install espnet)
# 2. torch(need installation: pip install torch)
# 3. display tool(will change according to needs)
#
# *This is not needed for data generation, but will be needed for future step:\
# pip install -q espnet==0.10.3 pyopenjtalk==0.1.5 parallel_wavegan==0.5.3 espnet_model_zoo

# %% [markdown]
# # 2. Text2speech model demo

# %% [markdown]
# ## 2.1 Configure params - English

# %%
#@title Choose English model { run: "auto" }
lang = 'English'
tag = 'kan-bayashi/ljspeech_vits' #@param ["kan-bayashi/ljspeech_tacotron2", "kan-bayashi/ljspeech_fastspeech", "kan-bayashi/ljspeech_fastspeech2", "kan-bayashi/ljspeech_conformer_fastspeech2", "kan-bayashi/ljspeech_joint_finetune_conformer_fastspeech2_hifigan", "kan-bayashi/ljspeech_joint_train_conformer_fastspeech2_hifigan", "kan-bayashi/ljspeech_vits"] {type:"string"}
vocoder_tag = "none" #@param ["none", "parallel_wavegan/ljspeech_parallel_wavegan.v1", "parallel_wavegan/ljspeech_full_band_melgan.v2", "parallel_wavegan/ljspeech_multi_band_melgan.v2", "parallel_wavegan/ljspeech_hifigan.v1", "parallel_wavegan/ljspeech_style_melgan.v1"] {type:"string"}

# %% [markdown]
# ## 2.2 build model using params

# %%
import numpy as np
import espnet
from espnet2.bin.tts_inference import Text2Speech
from espnet2.utils.types import str_or_none

text2speech = Text2Speech.from_pretrained(
    model_tag=str_or_none(tag),
    vocoder_tag=str_or_none(vocoder_tag),
    #device="cuda",
    # Only for Tacotron 2 & Transformer
    threshold=0.5,
    # Only for Tacotron 2
    minlenratio=0.0,
    maxlenratio=10.0,
    use_att_constraint=False,
    backward_window=1,
    forward_window=3,
    # Only for FastSpeech & FastSpeech2 & VITS
    speed_control_alpha=1.0,
    # Only for VITS
    noise_scale=0.333,
    noise_scale_dur=0.333,
)

# %% [markdown]
# ## 2.3 display audio from text

# %%
import time
import torch
from IPython.display import display, Audio

text = "Hello, this is new text"

def displayTTS(text):
    # synthesis
    wav = text2speech(text)["wav"]

    # let us listen to generated samples
    display(Audio(wav.view(-1).cpu().numpy(), rate=text2speech.fs))

# %%
TTS("I MEAN OF COURSE IF YOU'LL TAKE A COMPANION")
# Out:
# <class 'torch.Tensor'>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = "I MEAN OF COURSE IF YOU'LL TAKE A COMPANION".lower()
TTS(text)
# Out:
# <class 'torch.Tensor'>
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # 3. output audio from text

# %% [markdown]
# ## 3.1 Save TTS to wav file

# %%
import soundfile as sf

def saveTTS(text, path, fileName):
    # synthesis
    wav = text2speech(text)["wav"]

    # output audio as fileName
    sf.write(path+fileName+".wav", wav.numpy(), text2speech.fs, "PCM_16")

# %%
text = "test save audio file"
rootPath = "LibriSpeech/"
fileName = "testOutput"
#saveTTS(text, rootPath, fileName)

# %% [markdown]
# ## 3.2 Utility Functions: make empty directory

# %%
from pathlib import Path
def makeDir(pathName):
    # if under current dir, pathName will just be dirName
    Path(pathName).mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## 3.3 Utility Functions: find path that contains all the goodie goodies

# %%
import os
def whereGoodiesDFS(rootPath, trainSetName):
    # trainSetName = "train-clean-100"
    goodies = []
    for dir1 in os.listdir(rootPath+trainSetName):
        newDir = rootPath+trainSetName+"/"+dir1
        if not os.path.isdir(newDir):
            continue
            
        if dir1 == ".DS_Store":
            continue
        for dir2 in os.listdir(rootPath+trainSetName+"/"+dir1):
            goodies.append(rootPath+trainSetName+"/"+dir1+"/"+dir2)
    return goodies

# %%
trainSetName = "train-clean-100"
allDir = whereGoodiesDFS(rootPath, trainSetName)
#print(allDir)
# Out:
# ['LibriSpeech/train-clean-100/1069/133709', 'LibriSpeech/train-clean-100/1069/133699', 'LibriSpeech/train-clean-100/8580/287364', 'LibriSpeech/train-clean-100/8580/287363', 'LibriSpeech/train-clean-100/3168/173564', 'LibriSpeech/train-clean-100/3168/173565', 'LibriSpeech/train-clean-100/909/131045', 'LibriSpeech/train-clean-100/909/131044', 'LibriSpeech/train-clean-100/909/131041', 'LibriSpeech/train-clean-100/307/127535', 'LibriSpeech/train-clean-100/307/127539', 'LibriSpeech/train-clean-100/307/127540', 'LibriSpeech/train-clean-100/1263/139804', 'LibriSpeech/train-clean-100/1263/141777', 'LibriSpeech/train-clean-100/1263/138246', 'LibriSpeech/train-clean-100/2843/152918', 'LibriSpeech/train-clean-100/6880/216547', 'LibriSpeech/train-clean-100/103/1240', 'LibriSpeech/train-clean-100/103/1241', 'LibriSpeech/train-clean-100/8770/295465', 'LibriSpeech/train-clean-100/8770/295462', 'LibriSpeech/train-clean-100/8770/295463', 'LibriSpeech/train-clean-100/1034/121119', 'LibriSpeech/train-clean-100/5652/19215', 'LibriSpeech/train-clean-100/5652/39938', 'LibriSpeech/train-clean-100/6818/68772', 'LibriSpeech/train-clean-100/6818/76332', 'LibriSpeech/train-clean-100/150/126107', 'LibriSpeech/train-clean-100/150/132655', 'LibriSpeech/train-clean-100/150/126112', 'LibriSpeech/train-clean-100/2817/142371', 'LibriSpeech/train-clean-100/2817/142380', 'LibriSpeech/train-clean-100/32/21634', 'LibriSpeech/train-clean-100/32/4137', 'LibriSpeech/train-clean-100/32/21631', 'LibriSpeech/train-clean-100/32/21625', 'LibriSpeech/train-clean-100/6476/96661', 'LibriSpeech/train-clean-100/6476/57446', 'LibriSpeech/train-clean-100/730/359', 'LibriSpeech/train-clean-100/730/358', 'LibriSpeech/train-clean-100/730/360', 'LibriSpeech/train-clean-100/5456/62043', 'LibriSpeech/train-clean-100/5456/24741', 'LibriSpeech/train-clean-100/5456/62014', 'LibriSpeech/train-clean-100/5456/58161', 'LibriSpeech/train-clean-100/8312/279791', 'LibriSpeech/train-clean-100/8312/279790', 'LibriSpeech/train-clean-100/6415/116629', 'LibriSpeech/train-clean-100/6415/111615', 'LibriSpeech/train-clean-100/6415/100596', 'LibriSpeech/train-clean-100/6078/54007', 'LibriSpeech/train-clean-100/6078/54013', 'LibriSpeech/train-clean-100/8324/286681', 'LibriSpeech/train-clean-100/8324/286683', 'LibriSpeech/train-clean-100/8324/286682', 'LibriSpeech/train-clean-100/7505/258958', 'LibriSpeech/train-clean-100/7505/83618', 'LibriSpeech/train-clean-100/7505/258964', 'LibriSpeech/train-clean-100/1898/145720', 'LibriSpeech/train-clean-100/1898/145702', 'LibriSpeech/train-clean-100/1898/145715', 'LibriSpeech/train-clean-100/1898/145724', 'LibriSpeech/train-clean-100/8747/293952', 'LibriSpeech/train-clean-100/2289/152257', 'LibriSpeech/train-clean-100/2289/152258', 'LibriSpeech/train-clean-100/2289/152254', 'LibriSpeech/train-clean-100/2289/152253', 'LibriSpeech/train-clean-100/6272/70168', 'LibriSpeech/train-clean-100/6272/70171', 'LibriSpeech/train-clean-100/6272/70191', 'LibriSpeech/train-clean-100/60/121082', 'LibriSpeech/train-clean-100/4788/94904', 'LibriSpeech/train-clean-100/4788/294466', 'LibriSpeech/train-clean-100/4788/91208', 'LibriSpeech/train-clean-100/5808/48608', 'LibriSpeech/train-clean-100/5808/54425', 'LibriSpeech/train-clean-100/8465/246942', 'LibriSpeech/train-clean-100/8465/246943', 'LibriSpeech/train-clean-100/8465/246947', 'LibriSpeech/train-clean-100/8465/246940', 'LibriSpeech/train-clean-100/4051/11217', 'LibriSpeech/train-clean-100/4051/11218', 'LibriSpeech/train-clean-100/4051/10927', 'LibriSpeech/train-clean-100/229/130880', 'LibriSpeech/train-clean-100/4297/13009', 'LibriSpeech/train-clean-100/4297/13006', 'LibriSpeech/train-clean-100/211/122425', 'LibriSpeech/train-clean-100/211/122442', 'LibriSpeech/train-clean-100/5514/19192', 'LibriSpeech/train-clean-100/5514/19193', 'LibriSpeech/train-clean-100/2952/408', 'LibriSpeech/train-clean-100/2952/407', 'LibriSpeech/train-clean-100/2952/410', 'LibriSpeech/train-clean-100/7078/271888', 'LibriSpeech/train-clean-100/3242/6715 ...

# %% [markdown]
# ## 3.4 Utility Functions: find text and retrieve label and sentence

# %%
import glob
import pandas as pd

def getMetaInfo(dirPath):
    txtFileName = glob.glob(dirPath+'/*.txt')[0]
    column_names = ["label", "text"]
    df = pd.DataFrame(columns = column_names)
    with open(txtFileName) as f:
        lines = f.readlines()
    for line in lines:
        label = line.split()[0]
        text = line[len(label)+1:]
        row = {"label": label, "text":text}
        df = df.append(row, ignore_index = True)
    return df

# %%
samplePath = allDir[0]
metaInfo = getMetaInfo(samplePath)
print(samplePath)
metaInfo
# Out:
# LibriSpeech/train-clean-100/1069/133709
#                label                                               text
# 0   1069-133709-0000  HAD LAID BEFORE HER A PAIR OF ALTERNATIVES NOW...
# 1   1069-133709-0001  PROPERTY ERECTS A KIND OF BARRIER YOU CAN DO A...
# 2   1069-133709-0002  I MEAN OF COURSE IF YOU'LL TAKE A COMPANION SO...
# 3   1069-133709-0003          SHE'D KEEP PEOPLE OFF VERY WELL I THINK\n
# 4   1069-133709-0004  THAT IT'S A GREAT DEAL BETTER YOU SHOULD REMAI...
# 5   1069-133709-0005  SHE HAD A GREAT REGARD FOR WHAT WAS USUALLY DE...
# 6   1069-133709-0006  WHEN SHE SAT IN HER DAMP WATERPROOF AND SKETCH...
# 7   1069-133709-0007  AND HER IMAGINATION CONSTANTLY ANTICIPATED THE...
# 8   1069-133709-0008  BUT WAS NEVER OVER INQUISITIVE AS REGARDS THE ...
# 9   1069-133709-0009  SO LITTLE SURFACE OFFERED SO LIMITED A FACE TO...
# 10  1069-133709-0010  NO WIND SOWN BLOSSOM NO FAMILIAR SOFTENING MOS...
# 11  1069-133709-0011  SHE WAS LEARNING TO SACRIFICE CONSISTENCY TO C...
# 12  1069-133709-0012  THAT SHE SHOULD HAVE GONE THE LONGEST WAY ROUN...
# 13  1069-133709-0013  THAT WHEN RALPH WISHED TO SEE HER HE WAS AT LI...
# 14  1069-133709-0014  ISABEL SAID TO THIS YOUNG MAN THE DAY AFTER HE...
# 15  1069-133709-0015  WHAT DOES IT MATTER MY DEAR ISABEL WHETHER I K...
# 16  1069-133709-0016  ASKED ISABEL ABRUPTLY WHY AS A KIND OF COMPLIM...
# 17  1069-133709-0017  IF I BELIEVED THAT I SHOULD BE VERY UNHAPPY FO...
# 18  1069-133709-0018  IS AFTER ALL A FLORID SORT OF SENTIMENT I'M NO...
# 19  1069-133709-0019  YOU SEEM TO ME TROUBLED SAID RALPH I AM TROUBL...
# 20  1069-133709-0020  HENRIETTA DOESN'T OH HANG HENRIETTA SAID RALPH...
# 21  1069-133709-0021  RALPH WENT ON MORE GRAVELY I THINK IT VERY GOO...
# 22  1069-133709-0022  DON'T QUESTION YOUR CONSCIENCE SO MUCH IT WILL...
# 23  1069-133709-0023  LIVE AS YOU LIKE BEST AND YOUR CHARACTER WILL ...
# 24  1069-133709-0024  ISABEL HAD LISTENED QUICKLY YOU'VE TOO MUCH PO...
# 25  1069-133709-0025  IT'S NEVER WRONG TO DO THAT SHE HAD LISTENED E...
# 26  1069-133709-0026  BUT I THINK I'M RIGHT SAID RALPH PERSISTING IN...
# 27  1069-133709-0027  WHY INDEED SHOULD WE PERPETUALLY BE THINKING W...
# 28  1069-133709-0028  YOU'RE A CAPITAL PERSON TO ADVISE SAID RALPH Y...
# 29  1069-133709-0029  A LARGE FORTUNE MEANS FREEDOM AND I'M AFRAID O...
# 30  1069-133709-0030  I'M NOT SURE IT'S NOT A GREATER HAPPINESS TO B...
# 31  1069-133709-0031  THE GATE OF ADMIRATIONS ITALY AS YET IMPERFECT...
# 32  1069-133709-0032  WHENEVER SHE STROLLED UPON THE SHORE WITH HER ...
# 33  1069-133709-0033  SHE WAS GLAD TO PAUSE HOWEVER ON THE EDGE OF T...
# 34  1069-133709-0034  AS YET FOR REGARDING AS AGITATED BUT WHICH NEV...
# 35  1069-133709-0035  MADAME MERLE HAD PREDICTED TO MISSUS TOUCHETT ...
# 36  1069-133709-0036  GROWN USED TO FEELING RICH THE CONSCIOUSNESS I...
# 37  1069-133709-0037  IT TOOK PERPETUALLY FOR GRANTED A THOUSAND GOO...
# 38  1069-133709-0038  WERE SUBLIME IN THE MASS HER FORTUNE THEREFORE...
# 39  1069-133709-0039  WHICH IN SPITE OF INCREASING DISTANCE WERE STI...
# 40  1069-133709-0040  SHE COULD SUMMON BACK HER FAITH IN CASE OF NEE...
# 41  1069-133709-0041  LIVID LIGHT OF A JUDGEMENT DAY THE GIRL MOREOV...
# 42  1069-133709-0042  SHE WAS CAPABLE OF BEING WOUNDED BY THE DISCOV...
# 43  1069-133709-0043  EITHER TO CASPAR GOODWOOD OR TO LORD WARBURTON...
# 44  1069-133709-0044  AND IN THAT TIME A GREAT MANY THINGS MIGHT HAP...
# 45  1069-133709-0045  SHE HAD NOT THE SMALLEST BELIEF THAT THIS MERI...
# 46  1069-133709-0046  A CLEAR AND QUIET HARBOUR ENCLOSED BY A BRAVE ...
# 47  1069-133709-0047  SEEMED TO HER MORE THAN A NOBLE HUMILITY OR AN...
# 48  1069-133709-0048  WOULD BE EMINENTLY JUST THIS WAS NOT AS IT MAY...
# 49  1069-133709-0049  HE HAD BEEN DEEPLY AFFECTED THIS SHE BELIEVED ...
# 50  1069-133709-0050  SHOULD CULTIVATE A SCAR OUT OF PROPORTION TO A...
# 51  1069-133709-0051  WHO HAD BEEN BUT A CASUAL ACQUAINTANCE SHE FLA...
# 52  1069-133709-0052  SHE SHOULD RECEIVE THE NEWS WITHOUT A PANG EVE...

# %% [markdown]
# ## 3.4 Utility Functions: generate TTS wav and put into TTS dir

# %%
def generateTTS(dirPath):
    # Ex. dirPath = LibriSpeech/train-clean-100/1069/133709
    
    #1. setup empty dir inside
    ttsPath = dirPath+"/TTS"
    makeDir(ttsPath)
    
    #2. get metaInfo
    metaInfo = getMetaInfo(dirPath)
    
    #3. generate TTS wav and put inside TTS
    for _, row in metaInfo.iterrows():
        label = row[0]
        text = row[1]
        saveTTS(text, ttsPath+"/", label)
    print(dirPath+" done!")

# %%
#generateTTS(samplePath)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-174-b47880a6f0f4> in <module>
# ----> 1 generateTTS(samplePath)
#
# <ipython-input-173-8dfb8fa219dd> in generateTTS(dirPath)
#      13         label = row[0]
#      14         text = row[1]
# ---> 15         saveTTS(text, ttsPath+"/", label)
#      16     print(dirPath+" done!")
#
# <ipython-input-73-cc6aec266600> in saveTTS(text, path, fileName)
#       3 def saveTTS(text, path, fileName):
#       4     # synthesis
# ----> 5     wav = text2speech(text)["wav"]
#       6
#       7     # output audio as fileName
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      24         def decorate_context(*args, **kwargs):
#      25             with self.__class__():
# ---> 26                 return func(*args, **kwargs)
#      27         return cast(F, decorate_context)
#      28
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/bin/tts_inference.py in __call__(self, text, speech, durations, spembs, sids, lids, decode_conf)
#     202         if self.always_fix_seed:
#     203             set_all_random_seed(self.seed)
# --> 204         output_dict = self.model.inference(**batch, **cfg)
#     205
#     206         # calculate additional metrics
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/tts/espnet_model.py in inference(self, text, speech, spembs, sids, lids, durations, pitch, energy, **decode_config)
#     297             input_dict.update(lids=lids)
#     298
# --> 299         output_dict = self.tts.inference(**input_dict, **decode_config)
#     300
#     301         if self.normalize is not None and output_dict.get("feat_gen") is not None:
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/gan_tts/vits/vits.py in inference(self, text, feats, sids, spembs, lids, durations, noise_scale, noise_scale_dur, alpha, max_len, use_teacher_forcing)
#     597             )
#     598         else:
# --> 599             wav, att_w, dur = self.generator.inference(
#     600                 text=text,
#     601                 text_lengths=text_lengths,
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/gan_tts/vits/generator.py in inference(self, text, text_lengths, feats, feats_lengths, sids, spembs, lids, dur, noise_scale, noise_scale_dur, alpha, max_len, use_teacher_forcing)
#     549             z_p = m_p + torch.randn_like(m_p) * torch.exp(logs_p) * noise_scale
#     550             z = self.flow(z_p, y_mask, g=g, inverse=True)
# --> 551             wav = self.decoder((z * y_mask)[:, :, :max_len], g=g)
#     552
#     553         return wav.squeeze(1), attn.squeeze(1), dur.squeeze(1)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/gan_tts/hifigan/hifigan.py in forward(self, c, g)
#     158             cs = 0.0  # initialize
#     159             for j in range(self.num_blocks):
# --> 160                 cs += self.blocks[i * self.num_blocks + j](c)
#     161             c = cs / self.num_blocks
#     162         c = self.output_conv(c)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/espnet2/gan_tts/hifigan/residual_block.py in forward(self, x)
#      95             xt = self.convs1[idx](x)
#      96             if self.use_additional_convs:
# ---> 97                 xt = self.convs2[idx](xt)
#      98             x = xt + x
#      99         return x
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/container.py in forward(self, input)
#     115     def forward(self, input):
#     116         for module in self:
# --> 117             input = module(input)
#     118         return input
#     119
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     725             result = self._slow_forward(*input, **kwargs)
#     726         else:
# --> 727             result = self.forward(*input, **kwargs)
#     728         for hook in itertools.chain(
#     729                 _global_forward_hooks.values(),
#
# /usr/local/anaconda3/lib/python3.8/site-packages/torch/nn/modules/conv.py in forward(self, input)
#     256                             self.weight, self.bias, self.stride,
#     257                             _single(0), self.dilation, self.groups)
# --> 258         return F.conv1d(input, self.weight, self.bias, self.stride,
#     259                         self.padding, self.dilation, self.groups)
#     260
#
# KeyboardInterrupt:

# %% [markdown]
# ## 3.4 Final Step: GO GO GO!

# %%
def generateTTSforAll(trainSetName):
    rootPath = "LibriSpeech/"
    # 1. get all
    allDir = whereGoodiesDFS(rootPath, trainSetName)
    n = len(allDir)
    for i, dirPath in enumerate(allDir):
        if ".DS_Store" in dirPath:
            continue
        # 2. generate tts for each
        generateTTS(dirPath)
        print(str(i+1)+"/"+str(n)+" DONE")

# %%
trainSetName = "train-clean-100"
generateTTSforAll(trainSetName)
# Out:
# LibriSpeech/train-clean-100/1069/133709 done!
# 2/587 DONE
# LibriSpeech/train-clean-100/1069/133699 done!
# 3/587 DONE
# LibriSpeech/train-clean-100/8580/287364 done!
# 4/587 DONE
# LibriSpeech/train-clean-100/8580/287363 done!
# 5/587 DONE
# LibriSpeech/train-clean-100/3168/173564 done!
# 6/587 DONE
# LibriSpeech/train-clean-100/3168/173565 done!
# 7/587 DONE
# LibriSpeech/train-clean-100/909/131045 done!
# 8/587 DONE
# LibriSpeech/train-clean-100/909/131044 done!
# 9/587 DONE
# LibriSpeech/train-clean-100/909/131041 done!
# 10/587 DONE
# LibriSpeech/train-clean-100/307/127535 done!
# 11/587 DONE
# LibriSpeech/train-clean-100/307/127539 done!
# 12/587 DONE
# LibriSpeech/train-clean-100/307/127540 done!
# 13/587 DONE
# LibriSpeech/train-clean-100/1263/139804 done!
# 14/587 DONE
# LibriSpeech/train-clean-100/1263/141777 done!
# 15/587 DONE
# LibriSpeech/train-clean-100/1263/138246 done!
# 16/587 DONE
# LibriSpeech/train-clean-100/2843/152918 done!
# 17/587 DONE
# LibriSpeech/train-clean-100/6880/216547 done!
# 18/587 DONE
# LibriSpeech/train-clean-100/103/1240 done!
# 19/587 DONE
# LibriSpeech/train-clean-100/103/1241 done!
# 20/587 DONE
# LibriSpeech/train-clean-100/8770/295465 done!
# 21/587 DONE
# LibriSpeech/train-clean-100/8770/295462 done!
# 22/587 DONE
# LibriSpeech/train-clean-100/8770/295463 done!
# 23/587 DONE
# LibriSpeech/train-clean-100/1034/121119 done!
# 24/587 DONE
# LibriSpeech/train-clean-100/5652/19215 done!
# 25/587 DONE
# LibriSpeech/train-clean-100/5652/39938 done!
# 26/587 DONE
# LibriSpeech/train-clean-100/6818/68772 done!
# 27/587 DONE
# LibriSpeech/train-clean-100/6818/76332 done!
# 28/587 DONE
# LibriSpeech/train-clean-100/150/126107 done!
# 29/587 DONE
# LibriSpeech/train-clean-100/150/132655 done!
# 30/587 DONE
# LibriSpeech/train-clean-100/150/126112 done!
# 31/587 DONE
# LibriSpeech/train-clean-100/2817/142371 done!
# 32/587 DONE
# LibriSpeech/train-clean-100/2817/142380 done!
# 33/587 DONE
# LibriSpeech/train-clean-100/32/21634 done!
# 34/587 DONE
# LibriSpeech/train-clean-100/32/4137 done!
# 35/587 DONE
# LibriSpeech/train-clean-100/32/21631 done!
# 36/587 DONE
# LibriSpeech/train-clean-100/32/21625 done!
# 37/587 DONE
# LibriSpeech/train-clean-100/6476/96661 done!
# 38/587 DONE
# LibriSpeech/train-clean-100/6476/57446 done!
# 39/587 DONE
# LibriSpeech/train-clean-100/730/359 done!
# 40/587 DONE
# LibriSpeech/train-clean-100/730/358 done!
# 41/587 DONE
# LibriSpeech/train-clean-100/730/360 done!
# 42/587 DONE
# LibriSpeech/train-clean-100/5456/62043 done!
# 43/587 DONE
# LibriSpeech/train-clean-100/5456/24741 done!
# 44/587 DONE
# LibriSpeech/train-clean-100/5456/62014 done!
# 45/587 DONE
# LibriSpeech/train-clean-100/5456/58161 done!
# 46/587 DONE
# LibriSpeech/train-clean-100/8312/279791 done!
# 47/587 DONE
# LibriSpeech/train-clean-100/8312/279790 done!
# 48/587 DONE
# LibriSpeech/train-clean-100/6415/116629 done!
# 49/587 DONE
# LibriSpeech/train-clean-100/6415/111615 done!
# 50/587 DONE
# LibriSpeech/train-clean-100/6415/100596 done!
# 51/587 DONE
# LibriSpeech/train-clean-100/6078/54007 done!
# 52/587 DONE
# LibriSpeech/train-clean-100/6078/54013 done!
# 53/587 DONE
# LibriSpeech/train-clean-100/8324/286681 done!
# 54/587 DONE
# LibriSpeech/train-clean-100/8324/286683 done!
# 55/587 DONE
# LibriSpeech/train-clean-100/8324/286682 done!
# 56/587 DONE
# LibriSpeech/train-clean-100/7505/258958 done!
# 57/587 DONE
# LibriSpeech/train-clean-100/7505/83618 done!
# 58/587 DONE
# LibriSpeech/train-clean-100/7505/258964 done!
# 59/587 DONE
# LibriSpeech/train-clean-100/1898/145720 done!
# 60/587 DONE
# LibriSpeech/train-clean-100/1898/145702 done!
# 61/587 DONE
# LibriSpeech/train-clean-100/1898/145715 done!
# 62/587 DONE
# LibriSpeech/train-clean-100/1898/145724 done!
# 63/587 DONE
# LibriSpeech/train-clean-100/8747/293952 done!
# 64/587 DONE
# LibriSpeech/train-clean-100/2289/152257 done!
# 65/587 DONE
# LibriSpeech/train-clean-100/2289/152258 done!
# 66/587 DONE
# LibriSpeech/train-clean-100/2289/152254 done!
# 67/587 DONE
# LibriSpeech/train-clean-100/2289/152253 done!
# 68/587 DONE
# LibriSpeech/train-clean-100/6272/70168 done!
# 69/587 DONE
# LibriSpeech/train-clean-100/6272/70171 done!
# 70/587 DONE
# LibriSpeech/train-clean-100/6272/70191 done!
# 71/587 DONE
# LibriSpeech/train-clean-100/60/121082 done!
# 72/587 DONE
# LibriSpeech/train-clean-100/4788/94904 done!
# 73/587 DONE
# LibriSpeech/train-clean-100/4788/294466 done!
# 74/587 DONE
# LibriSpeech/train-clean-100/4788/91208 done!
# 75/587 DONE
# LibriSpeech/train-clean-100/5808/48608 done!
# 76/587 DONE
# LibriSpeech/train-clean-100/5808/54425 done!
# 77/587 DONE
# LibriSpeech/train-clean-100/8465/246942 done!
# 78/587 DONE
# LibriSpeech/train-clean-100/8465/246943 done!
# 79/587 DONE
# LibriSpeech/train-clean-100/8465/246947 done!
# 80/587 DONE
# LibriSpeech/train-clean-100/8465/246940 done!
# 81/587 DONE
# LibriSpeech/train-clean-100/4051/11217 done!
# 82/587 DONE
# LibriSpeech/train-clean-100/4051/11218 done!
# 83/587 DONE
# LibriSpeech/train-clean-100/4051/10927 done!
# 84/587 DONE
# LibriSpeech/train-clean-100/229/130880 done!
# 85/587 DONE
# LibriSpeech/train-clean-100/4297/13009 done!
# 86/587 DONE
# LibriSpeech/train-clean-100/4297/13006 done!
# 87/587 DONE
# LibriSpeech/train-clean-100/211/122425 done!
# 88/587 DONE
# LibriSpeech/train-clean-100/211/122442 done!
# 89/587 DONE
# LibriSpeech/train-clean-100/5514/19192 done!
# 90/587 DONE
# LibriSpeech/train-clean-100/5514/19193 done!
# 91/587 DONE
# LibriSpeech/train-clean-100/2952/408 done!
# 92/587 DONE
# LibriSpeech/train-clean-100/2952/407 done!
# 93/587 DONE
# LibriSpeech/train-clean-100/2952/410 done!
# 94/587 DONE
# LibriSpeech/train-clean-100/7078/271888 done!
# 95/587 DONE
# LibriSpeech/train-clean-100/3242/67153 done!
# 96/587 DONE
# LibriSpeech/train-clean-100/3242/67168 done!
# 97/587 DONE
# LibriSpeech/train-clean-100/3242/8112 done!
# 98/587 DONE
# LibriSpeech/train-clean-100/3440/171006 done!
# 99/587 DONE
# LibriSpeech/train-clean-100/3440/171009 done!
# 100/587 DONE
# LibriSpeech/train-clean-100/7226/86965 done!
# 101/587 DONE
# LibriSpeech/train-clean-100/7226/86964 done!
# 102/587 DONE
# LibriSpeech/train-clean-100/4830/25898 done!
# 103/587 DONE
# LibriSpeech/train-clean-100/4830/25904 done!
# 104/587 DONE
# LibriSpeech/train-clean-100/1926/147979 done!
# 105/587 DONE
# LibriSpeech/train-clean-100/1926/143879 done!
# 106/587 DONE
# LibriSpeech/train-clean-100/1926/147987 done!
# 107/587 DONE
# LibriSpeech/train-clean-100/8063/274116 done!
# 108/587 DONE
# LibriSpeech/train-clean-100/8063/274117 done!
# 109/587 DONE
# LibriSpeech/train-clean-100/8063/274115 done!
# 110/587 DONE
# LibriSpeech/train-clean-100/8063/274112 done!
# 111/587 DONE
# LibriSpeech/train-clean-100/887/123289 done!
# 112/587 DONE
# LibriSpeech/train-clean-100/887/123290 done!
# 113/587 DONE
# LibriSpeech/train-clean-100/887/123291 done!
# 114/587 DONE
# LibriSpeech/train-clean-100/289/121652 done!
# 115/587 DONE
# LibriSpeech/train-clean-100/289/121665 done!
# 116/587 DONE
# LibriSpeech/train-clean-100/2391/145015 done!
# 117/587 DONE
# LibriSpeech/train-clean-100/226/122538 done!
# 118/587 DONE
# LibriSpeech/train-clean-100/226/131533 done!
# 119/587 DONE
# LibriSpeech/train-clean-100/226/131532 done!
# 120/587 DONE
# LibriSpeech/train-clean-100/1183/128659 done!
# 121/587 DONE
# LibriSpeech/train-clean-100/1183/133256 done!
# 122/587 DONE
# LibriSpeech/train-clean-100/1183/124566 done!
# 123/587 DONE
# LibriSpeech/train-clean-100/1183/133255 done!
# 124/587 DONE
# LibriSpeech/train-clean-100/446/123502 done!
# 125/587 DONE
# LibriSpeech/train-clean-100/446/123501 done!
# 126/587 DONE
# LibriSpeech/train-clean-100/2159/179157 done!
# 127/587 DONE
# LibriSpeech/train-clean-100/2159/179156 done!
# 128/587 DONE
# LibriSpeech/train-clean-100/2159/179154 done!
# 129/587 DONE
# LibriSpeech/train-clean-100/441/128982 done!
# 130/587 DONE
# LibriSpeech/train-clean-100/441/130108 done!
# 131/587 DONE
# LibriSpeech/train-clean-100/441/128988 done!
# 132/587 DONE
# LibriSpeech/train-clean-100/4853/27671 done!
# 133/587 DONE
# LibriSpeech/train-clean-100/4853/27670 done!
# 134/587 DONE
# LibriSpeech/train-clean-100/4853/29413 done!
# 135/587 DONE
# LibriSpeech/train-clean-100/4898/28461 done!
# 136/587 DONE
# LibriSpeech/train-clean-100/4898/20016 done!
# 137/587 DONE
# LibriSpeech/train-clean-100/7447/91186 done!
# 138/587 DONE
# LibriSpeech/train-clean-100/7447/91187 done!
# 139/587 DONE
# LibriSpeech/train-clean-100/8098/278278 done!
# 140/587 DONE
# LibriSpeech/train-clean-100/8098/275181 done!
# 141/587 DONE
# LibriSpeech/train-clean-100/8098/278252 done!
# 142/587 DONE
# LibriSpeech/train-clean-100/1743/142912 done!
# 143/587 DONE
# LibriSpeech/train-clean-100/1743/142913 done!
# 144/587 DONE
# LibriSpeech/train-clean-100/1743/142914 done!
# 145/587 DONE
# LibriSpeech/train-clean-100/2764/36616 done!
# 146/587 DONE
# LibriSpeech/train-clean-100/2764/36619 done!
# 147/587 DONE
# LibriSpeech/train-clean-100/2764/36617 done!
# 148/587 DONE
# LibriSpeech/train-clean-100/412/126975 done!
# 149/587 DONE
# LibriSpeech/train-clean-100/1578/6379 done!
# 150/587 DONE
# LibriSpeech/train-clean-100/1578/140045 done!
# 151/587 DONE
# LibriSpeech/train-clean-100/1578/140049 done!
# 152/587 DONE
# LibriSpeech/train-clean-100/5789/57195 done!
# 153/587 DONE
# LibriSpeech/train-clean-100/5789/57158 done!
# 154/587 DONE
# LibriSpeech/train-clean-100/5789/70653 done!
# 155/587 DONE
# LibriSpeech/train-clean-100/4813/248641 done!
# 156/587 DONE
# LibriSpeech/train-clean-100/4813/248638 done!
# 157/587 DONE
# LibriSpeech/train-clean-100/8629/261139 done!
# 158/587 DONE
# LibriSpeech/train-clean-100/8629/261140 done!
# 159/587 DONE
# LibriSpeech/train-clean-100/3235/28433 done!
# 160/587 DONE
# LibriSpeech/train-clean-100/3235/28452 done!
# 161/587 DONE
# LibriSpeech/train-clean-100/3235/11599 done!
# 162/587 DONE
# LibriSpeech/train-clean-100/1334/135589 done!
# 163/587 DONE
# LibriSpeech/train-clean-100/250/142286 done!
# 164/587 DONE
# LibriSpeech/train-clean-100/250/140277 done!
# 165/587 DONE
# LibriSpeech/train-clean-100/250/142276 done!
# 166/587 DONE
# LibriSpeech/train-clean-100/1553/140047 done!
# 167/587 DONE
# LibriSpeech/train-clean-100/1553/140048 done!
# 168/587 DONE
# LibriSpeech/train-clean-100/4214/7146 done!
# 169/587 DONE
# LibriSpeech/train-clean-100/2518/154825 done!
# 170/587 DONE
# LibriSpeech/train-clean-100/2518/154826 done!
# 171/587 DONE
# LibriSpeech/train-clean-100/669/129061 done!
# 172/587 DONE
# LibriSpeech/train-clean-100/669/129074 done!
# 173/587 DONE
# LibriSpeech/train-clean-100/3259/158083 done!
# 174/587 DONE
# LibriSpeech/train-clean-100/3857/182317 done!
# 175/587 DONE
# LibriSpeech/train-clean-100/3857/180923 done!
# 176/587 DONE
# LibriSpeech/train-clean-100/3857/182315 done!
# 177/587 DONE
# LibriSpeech/train-clean-100/4088/158079 done!
# 178/587 DONE
# LibriSpeech/train-clean-100/4088/158077 done!
# 179/587 DONE
# LibriSpeech/train-clean-100/7635/105661 done!
# 180/587 DONE
# LibriSpeech/train-clean-100/7635/105409 done!
# 181/587 DONE
# LibriSpeech/train-clean-100/8226/274371 done!
# 182/587 DONE
# LibriSpeech/train-clean-100/8226/274369 done!
# 183/587 DONE
# LibriSpeech/train-clean-100/8014/112602 done!
# 184/587 DONE
# LibriSpeech/train-clean-100/8014/112586 done!
# 185/587 DONE
# LibriSpeech/train-clean-100/8014/280382 done!
# 186/587 DONE
# LibriSpeech/train-clean-100/4018/107338 done!
# 187/587 DONE
# LibriSpeech/train-clean-100/4018/107312 done!
# 188/587 DONE
# LibriSpeech/train-clean-100/4018/103416 done!
# 189/587 DONE
# LibriSpeech/train-clean-100/6925/80680 done!
# 190/587 DONE
# LibriSpeech/train-clean-100/5750/35690 done!
# 191/587 DONE
# LibriSpeech/train-clean-100/5750/100289 done!
# 192/587 DONE
# LibriSpeech/train-clean-100/4640/19189 done!
# 193/587 DONE
# LibriSpeech/train-clean-100/4640/19187 done!
# 194/587 DONE
# LibriSpeech/train-clean-100/4640/19188 done!
# 195/587 DONE
# LibriSpeech/train-clean-100/8425/292520 done!
# 196/587 DONE
# LibriSpeech/train-clean-100/8425/291444 done!
# 197/587 DONE
# LibriSpeech/train-clean-100/8425/246962 done!
# 198/587 DONE
# LibriSpeech/train-clean-100/8425/287387 done!
# 199/587 DONE
# LibriSpeech/train-clean-100/4481/17498 done!
# 200/587 DONE
# LibriSpeech/train-clean-100/4481/17499 done!
# 201/587 DONE
# LibriSpeech/train-clean-100/3436/172162 done!
# 202/587 DONE
# LibriSpeech/train-clean-100/3436/172171 done!
# 203/587 DONE
# LibriSpeech/train-clean-100/5163/39921 done!
# 204/587 DONE
# LibriSpeech/train-clean-100/5163/18515 done!
# 205/587 DONE
# LibriSpeech/train-clean-100/7859/102518 done!
# 206/587 DONE
# LibriSpeech/train-clean-100/7859/102519 done!
# 207/587 DONE
# LibriSpeech/train-clean-100/7859/102521 done!
# 208/587 DONE
# LibriSpeech/train-clean-100/6385/34669 done!
# 209/587 DONE
# LibriSpeech/train-clean-100/6385/34655 done!
# 210/587 DONE
# LibriSpeech/train-clean-100/6385/220959 done!
# 211/587 DONE
# LibriSpeech/train-clean-100/6181/216552 done!
# 212/587 DONE
# LibriSpeech/train-clean-100/233/155990 done!
# 213/587 DONE
# LibriSpeech/train-clean-100/233/134440 done!
# 214/587 DONE
# LibriSpeech/train-clean-100/5393/19218 done!
# 215/587 DONE
# LibriSpeech/train-clean-100/5393/19219 done!
# 216/587 DONE
# LibriSpeech/train-clean-100/2384/152900 done!
# 217/587 DONE
# LibriSpeech/train-clean-100/5703/47198 done!
# 218/587 DONE
# LibriSpeech/train-clean-100/5703/47212 done!
# 219/587 DONE
# LibriSpeech/train-clean-100/6529/62554 done!
# 220/587 DONE
# LibriSpeech/train-clean-100/6529/62556 done!
# 221/587 DONE
# LibriSpeech/train-clean-100/1992/141719 done!
# 222/587 DONE
# LibriSpeech/train-clean-100/6000/86686 done!
# 223/587 DONE
# LibriSpeech/train-clean-100/6000/55211 done!
# 224/587 DONE
# LibriSpeech/train-clean-100/27/123349 done!
# 225/587 DONE
# LibriSpeech/train-clean-100/27/124992 done!
# 226/587 DONE
# LibriSpeech/train-clean-100/5678/43302 done!
# 227/587 DONE
# LibriSpeech/train-clean-100/5678/43303 done!
# 228/587 DONE
# LibriSpeech/train-clean-100/5678/43301 done!
# 229/587 DONE
# LibriSpeech/train-clean-100/4137/11701 done!
# 230/587 DONE
# LibriSpeech/train-clean-100/4137/11702 done!
# 231/587 DONE
# LibriSpeech/train-clean-100/2436/2477 done!
# 232/587 DONE
# LibriSpeech/train-clean-100/2436/2476 done!
# 233/587 DONE
# LibriSpeech/train-clean-100/2436/2481 done!
# 234/587 DONE
# LibriSpeech/train-clean-100/1081/125237 done!
# 235/587 DONE
# LibriSpeech/train-clean-100/1081/128618 done!
# 236/587 DONE
# LibriSpeech/train-clean-100/89/218 done!
# 237/587 DONE
# LibriSpeech/train-clean-100/89/219 done!
# 238/587 DONE
# LibriSpeech/train-clean-100/3983/5371 done!
# 239/587 DONE
# LibriSpeech/train-clean-100/3983/5331 done!
# 240/587 DONE
# LibriSpeech/train-clean-100/1624/142933 done!
# 241/587 DONE
# LibriSpeech/train-clean-100/1624/168623 done!
# 242/587 DONE
# LibriSpeech/train-clean-100/6437/66173 done!
# 243/587 DONE
# LibriSpeech/train-clean-100/6437/66172 done!
# 244/587 DONE
# LibriSpeech/train-clean-100/118/121721 done!
# 245/587 DONE
# LibriSpeech/train-clean-100/118/47824 done!
# 246/587 DONE
# LibriSpeech/train-clean-100/118/124588 done!
# 247/587 DONE
# LibriSpeech/train-clean-100/7511/102420 done!
# 248/587 DONE
# LibriSpeech/train-clean-100/7511/102419 done!
# 249/587 DONE
# LibriSpeech/train-clean-100/87/121553 done!
# 250/587 DONE
# LibriSpeech/train-clean-100/3526/176651 done!
# 251/587 DONE
# LibriSpeech/train-clean-100/3526/175658 done!
# 252/587 DONE
# LibriSpeech/train-clean-100/3526/176653 done!
# 253/587 DONE
# LibriSpeech/train-clean-100/1088/134318 done!
# 254/587 DONE
# LibriSpeech/train-clean-100/1088/134315 done!
# 255/587 DONE
# LibriSpeech/train-clean-100/1088/129236 done!
# 256/587 DONE
# LibriSpeech/train-clean-100/2893/139322 done!
# 257/587 DONE
# LibriSpeech/train-clean-100/2893/139310 done!
# 258/587 DONE
# LibriSpeech/train-clean-100/2007/149877 done!
# 259/587 DONE
# LibriSpeech/train-clean-100/2007/132570 done!
# 260/587 DONE
# LibriSpeech/train-clean-100/6454/120342 done!
# 261/587 DONE
# LibriSpeech/train-clean-100/6454/107462 done!
# 262/587 DONE
# LibriSpeech/train-clean-100/6454/93938 done!
# 263/587 DONE
# LibriSpeech/train-clean-100/19/227 done!
# 264/587 DONE
# LibriSpeech/train-clean-100/19/198 done!
# 266/587 DONE
# LibriSpeech/train-clean-100/7312/92432 done!
# 267/587 DONE
# LibriSpeech/train-clean-100/26/496 done!
# 268/587 DONE
# LibriSpeech/train-clean-100/26/495 done!
# 269/587 DONE
# LibriSpeech/train-clean-100/7517/100442 done!
# 270/587 DONE
# LibriSpeech/train-clean-100/7517/100429 done!
# 271/587 DONE
# LibriSpeech/train-clean-100/7517/100437 done!
# 272/587 DONE
# LibriSpeech/train-clean-100/1841/159771 done!
# 273/587 DONE
# LibriSpeech/train-clean-100/1841/150351 done!
# 274/587 DONE
# LibriSpeech/train-clean-100/1841/179183 done!
# 275/587 DONE
# LibriSpeech/train-clean-100/3947/13262 done!
# 276/587 DONE
# LibriSpeech/train-clean-100/3947/13260 done!
# 277/587 DONE
# LibriSpeech/train-clean-100/6064/300880 done!
# 278/587 DONE
# LibriSpeech/train-clean-100/6064/56165 done!
# 279/587 DONE
# LibriSpeech/train-clean-100/6064/56168 done!
# 280/587 DONE
# LibriSpeech/train-clean-100/322/124146 done!
# 281/587 DONE
# LibriSpeech/train-clean-100/322/124147 done!
# 282/587 DONE
# LibriSpeech/train-clean-100/8797/294123 done!
# 283/587 DONE
# LibriSpeech/train-clean-100/3723/171631 done!
# 284/587 DONE
# LibriSpeech/train-clean-100/3723/171115 done!
# 285/587 DONE
# LibriSpeech/train-clean-100/1246/124548 done!
# 286/587 DONE
# LibriSpeech/train-clean-100/1246/135815 done!
# 287/587 DONE
# LibriSpeech/train-clean-100/1246/124550 done!
# 288/587 DONE
# LibriSpeech/train-clean-100/587/41619 done!
# 289/587 DONE
# LibriSpeech/train-clean-100/587/41611 done!
# 290/587 DONE
# LibriSpeech/train-clean-100/587/54108 done!
# 291/587 DONE
# LibriSpeech/train-clean-100/3982/182255 done!
# 292/587 DONE
# LibriSpeech/train-clean-100/3982/178459 done!
# 293/587 DONE
# LibriSpeech/train-clean-100/8975/270782 done!
# 294/587 DONE
# LibriSpeech/train-clean-100/198/129977 done!
# 295/587 DONE
# LibriSpeech/train-clean-100/198/209 done!
# 296/587 DONE
# LibriSpeech/train-clean-100/198/126831 done!
# 297/587 DONE
# LibriSpeech/train-clean-100/5463/39173 done!
# 298/587 DONE
# LibriSpeech/train-clean-100/5463/39174 done!
# 299/587 DONE
# LibriSpeech/train-clean-100/7302/86815 done!
# 300/587 DONE
# LibriSpeech/train-clean-100/7302/86814 done!
# 301/587 DONE
# LibriSpeech/train-clean-100/196/122150 done!
# 302/587 DONE
# LibriSpeech/train-clean-100/196/122159 done!
# 303/587 DONE
# LibriSpeech/train-clean-100/196/122152 done!
# 304/587 DONE
# LibriSpeech/train-clean-100/7190/90543 done!
# 305/587 DONE
# LibriSpeech/train-clean-100/7190/90542 done!
# 306/587 DONE
# LibriSpeech/train-clean-100/2416/152137 done!
# 307/587 DONE
# LibriSpeech/train-clean-100/2416/152139 done!
# 308/587 DONE
# LibriSpeech/train-clean-100/332/128985 done!
# 309/587 DONE
# LibriSpeech/train-clean-100/6848/76049 done!
# 310/587 DONE
# LibriSpeech/train-clean-100/6848/252322 done!
# 311/587 DONE
# LibriSpeech/train-clean-100/6848/252323 done!
# 312/587 DONE
# LibriSpeech/train-clean-100/1867/148436 done!
# 313/587 DONE
# LibriSpeech/train-clean-100/1867/154075 done!
# 314/587 DONE
# LibriSpeech/train-clean-100/1867/154071 done!
# 315/587 DONE
# LibriSpeech/train-clean-100/7367/86737 done!
# 316/587 DONE
# LibriSpeech/train-clean-100/4340/15220 done!
# 317/587 DONE
# LibriSpeech/train-clean-100/1235/135884 done!
# 318/587 DONE
# LibriSpeech/train-clean-100/1235/135883 done!
# 319/587 DONE
# LibriSpeech/train-clean-100/1235/135887 done!
# 320/587 DONE
# LibriSpeech/train-clean-100/7794/295947 done!
# 321/587 DONE
# LibriSpeech/train-clean-100/7794/295948 done!
# 322/587 DONE
# LibriSpeech/train-clean-100/7794/295955 done!
# 323/587 DONE
# LibriSpeech/train-clean-100/163/122947 done!
# 324/587 DONE
# LibriSpeech/train-clean-100/163/121908 done!
# 325/587 DONE
# LibriSpeech/train-clean-100/1455/134435 done!
# 326/587 DONE
# LibriSpeech/train-clean-100/1455/138263 done!
# 327/587 DONE
# LibriSpeech/train-clean-100/6019/3185 done!
# 328/587 DONE
# LibriSpeech/train-clean-100/39/121916 done!
# 329/587 DONE
# LibriSpeech/train-clean-100/39/121915 done!
# 330/587 DONE
# LibriSpeech/train-clean-100/39/121914 done!
# 331/587 DONE
# LibriSpeech/train-clean-100/8123/275216 done!
# 332/587 DONE
# LibriSpeech/train-clean-100/8123/275193 done!
# 333/587 DONE
# LibriSpeech/train-clean-100/8123/275209 done!
# 334/587 DONE
# LibriSpeech/train-clean-100/6081/42010 done!
# 335/587 DONE
# LibriSpeech/train-clean-100/6081/41998 done!
# 336/587 DONE
# LibriSpeech/train-clean-100/6081/41997 done!
# 337/587 DONE
# LibriSpeech/train-clean-100/5867/48852 done!
# 338/587 DONE
# LibriSpeech/train-clean-100/1098/133695 done!
# 339/587 DONE
# LibriSpeech/train-clean-100/302/123504 done!
# 340/587 DONE
# LibriSpeech/train-clean-100/302/123516 done!
# 341/587 DONE
# LibriSpeech/train-clean-100/302/123523 done!
# 342/587 DONE
# LibriSpeech/train-clean-100/426/122821 done!
# 343/587 DONE
# LibriSpeech/train-clean-100/426/122819 done!
# 344/587 DONE
# LibriSpeech/train-clean-100/426/122822 done!
# 345/587 DONE
# LibriSpeech/train-clean-100/5778/12761 done!
# 346/587 DONE
# LibriSpeech/train-clean-100/5778/54535 done!
# 347/587 DONE
# LibriSpeech/train-clean-100/248/130697 done!
# 348/587 DONE
# LibriSpeech/train-clean-100/248/130652 done!
# 349/587 DONE
# LibriSpeech/train-clean-100/248/130644 done!
# 350/587 DONE
# LibriSpeech/train-clean-100/8609/283227 done!
# 351/587 DONE
# LibriSpeech/train-clean-100/8609/262281 done!
# 352/587 DONE
# LibriSpeech/train-clean-100/6563/285357 done!
# 353/587 DONE
# LibriSpeech/train-clean-100/6563/63821 done!
# 354/587 DONE
# LibriSpeech/train-clean-100/625/132118 done!
# 355/587 DONE
# LibriSpeech/train-clean-100/625/132112 done!
# 356/587 DONE
# LibriSpeech/train-clean-100/3486/166424 done!
# 357/587 DONE
# LibriSpeech/train-clean-100/3486/166446 done!
# 358/587 DONE
# LibriSpeech/train-clean-100/8051/295385 done!
# 359/587 DONE
# LibriSpeech/train-clean-100/8051/118101 done!
# 360/587 DONE
# LibriSpeech/train-clean-100/8051/119902 done!
# 361/587 DONE
# LibriSpeech/train-clean-100/4267/72637 done!
# 362/587 DONE
# LibriSpeech/train-clean-100/4267/78186 done!
# 363/587 DONE
# LibriSpeech/train-clean-100/4267/287369 done!
# 364/587 DONE
# LibriSpeech/train-clean-100/7278/246956 done!
# 365/587 DONE
# LibriSpeech/train-clean-100/7278/91083 done!
# 366/587 DONE
# LibriSpeech/train-clean-100/7278/104730 done!
# 367/587 DONE
# LibriSpeech/train-clean-100/3879/173592 done!
# 368/587 DONE
# LibriSpeech/train-clean-100/3879/174923 done!
# 369/587 DONE
# LibriSpeech/train-clean-100/481/123720 done!
# 370/587 DONE
# LibriSpeech/train-clean-100/481/123719 done!
# 371/587 DONE
# LibriSpeech/train-clean-100/8468/286673 done!
# 372/587 DONE
# LibriSpeech/train-clean-100/8468/295198 done!
# 373/587 DONE
# LibriSpeech/train-clean-100/8468/294887 done!
# 374/587 DONE
# LibriSpeech/train-clean-100/1723/141149 done!
# 375/587 DONE
# LibriSpeech/train-clean-100/1116/137572 done!
# 376/587 DONE
# LibriSpeech/train-clean-100/1116/132851 done!
# 377/587 DONE
# LibriSpeech/train-clean-100/1116/132847 done!
# 378/587 DONE
# LibriSpeech/train-clean-100/2136/5140 done!
# 379/587 DONE
# LibriSpeech/train-clean-100/2136/5147 done!
# 380/587 DONE
# LibriSpeech/train-clean-100/2136/5143 done!
# 381/587 DONE
# LibriSpeech/train-clean-100/3214/167602 done!
# 382/587 DONE
# LibriSpeech/train-clean-100/3214/167607 done!
# 383/587 DONE
# LibriSpeech/train-clean-100/3214/167606 done!
# 384/587 DONE
# LibriSpeech/train-clean-100/8095/274346 done!
# 385/587 DONE
# LibriSpeech/train-clean-100/8095/274348 done!
# 386/587 DONE
# LibriSpeech/train-clean-100/8095/274345 done!
# 387/587 DONE
# LibriSpeech/train-clean-100/5322/7680 done!
# 388/587 DONE
# LibriSpeech/train-clean-100/5322/7679 done!
# 389/587 DONE
# LibriSpeech/train-clean-100/5322/7678 done!
# 390/587 DONE
# LibriSpeech/train-clean-100/8630/305212 done!
# 391/587 DONE
# LibriSpeech/train-clean-100/8630/305213 done!
# 392/587 DONE
# LibriSpeech/train-clean-100/4406/16883 done!
# 393/587 DONE
# LibriSpeech/train-clean-100/4406/16882 done!
# 394/587 DONE
# LibriSpeech/train-clean-100/1970/26100 done!
# 395/587 DONE
# LibriSpeech/train-clean-100/1970/10594 done!
# 396/587 DONE
# LibriSpeech/train-clean-100/1970/28415 done!
# 397/587 DONE
# LibriSpeech/train-clean-100/8238/283452 done!
# 398/587 DONE
# LibriSpeech/train-clean-100/8238/274553 done!
# 399/587 DONE
# LibriSpeech/train-clean-100/4859/26870 done!
# 400/587 DONE
# LibriSpeech/train-clean-100/4859/22176 done!
# 401/587 DONE
# LibriSpeech/train-clean-100/4859/29340 done!
# 402/587 DONE
# LibriSpeech/train-clean-100/3240/131231 done!
# 403/587 DONE
# LibriSpeech/train-clean-100/3240/131232 done!
# 404/587 DONE
# LibriSpeech/train-clean-100/2196/170379 done!
# 405/587 DONE
# LibriSpeech/train-clean-100/2196/174172 done!
# 406/587 DONE
# LibriSpeech/train-clean-100/2196/170151 done!
# 407/587 DONE
# LibriSpeech/train-clean-100/8838/298545 done!
# 408/587 DONE
# LibriSpeech/train-clean-100/8838/298546 done!
# 409/587 DONE
# LibriSpeech/train-clean-100/445/123860 done!
# 410/587 DONE
# LibriSpeech/train-clean-100/445/123857 done!
# 411/587 DONE
# LibriSpeech/train-clean-100/6367/74004 done!
# 412/587 DONE
# LibriSpeech/train-clean-100/6367/65536 done!
# 413/587 DONE
# LibriSpeech/train-clean-100/6531/61334 done!
# 414/587 DONE
# LibriSpeech/train-clean-100/458/126294 done!
# 415/587 DONE
# LibriSpeech/train-clean-100/458/126305 done!
# 416/587 DONE
# LibriSpeech/train-clean-100/458/126290 done!
# 417/587 DONE
# LibriSpeech/train-clean-100/1963/147036 done!
# 418/587 DONE
# LibriSpeech/train-clean-100/1963/142776 done!
# 419/587 DONE
# LibriSpeech/train-clean-100/1963/142393 done!
# 420/587 DONE
# LibriSpeech/train-clean-100/7264/92314 done!
# 421/587 DONE
# LibriSpeech/train-clean-100/7264/92310 done!
# 422/587 DONE
# LibriSpeech/train-clean-100/7264/92316 done!
# 423/587 DONE
# LibriSpeech/train-clean-100/1355/39947 done!
# 424/587 DONE
# LibriSpeech/train-clean-100/460/172359 done!
# 425/587 DONE
# LibriSpeech/train-clean-100/460/172357 done!
# 426/587 DONE
# LibriSpeech/train-clean-100/831/130746 done!
# 427/587 DONE
# LibriSpeech/train-clean-100/831/130739 done!
# 428/587 DONE
# LibriSpeech/train-clean-100/2182/181173 done!
# 429/587 DONE
# LibriSpeech/train-clean-100/2182/150130 done!
# 430/587 DONE
# LibriSpeech/train-clean-100/2182/181183 done!
# 431/587 DONE
# LibriSpeech/train-clean-100/1363/135842 done!
# 432/587 DONE
# LibriSpeech/train-clean-100/1363/139304 done!
# 433/587 DONE
# LibriSpeech/train-clean-100/200/124140 done!
# 434/587 DONE
# LibriSpeech/train-clean-100/200/124139 done!
# 435/587 DONE
# LibriSpeech/train-clean-100/200/126784 done!
# 436/587 DONE
# LibriSpeech/train-clean-100/5192/19396 done!
# 437/587 DONE
# LibriSpeech/train-clean-100/5192/19397 done!
# 438/587 DONE
# LibriSpeech/train-clean-100/7067/76048 done!
# 439/587 DONE
# LibriSpeech/train-clean-100/7067/76047 done!
# 440/587 DONE
# LibriSpeech/train-clean-100/405/130894 done!
# 441/587 DONE
# LibriSpeech/train-clean-100/405/130895 done!
# 442/587 DONE
# LibriSpeech/train-clean-100/298/126791 done!
# 443/587 DONE
# LibriSpeech/train-clean-100/298/126790 done!
# 444/587 DONE
# LibriSpeech/train-clean-100/4014/186183 done!
# 445/587 DONE
# LibriSpeech/train-clean-100/4014/186179 done!
# 446/587 DONE
# LibriSpeech/train-clean-100/4014/186176 done!
# 447/587 DONE
# LibriSpeech/train-clean-100/4014/186175 done!
# 448/587 DONE
# LibriSpeech/train-clean-100/254/145458 done!
# 449/587 DONE
# LibriSpeech/train-clean-100/254/27760 done!
# 450/587 DONE
# LibriSpeech/train-clean-100/254/127705 done!
# 451/587 DONE
# LibriSpeech/train-clean-100/254/12312 done!
# 452/587 DONE
# LibriSpeech/train-clean-100/3699/47246 done!
# 453/587 DONE
# LibriSpeech/train-clean-100/3699/19402 done!
# 454/587 DONE
# LibriSpeech/train-clean-100/3699/175950 done!
# 455/587 DONE
# LibriSpeech/train-clean-100/3699/19401 done!
# 456/587 DONE
# LibriSpeech/train-clean-100/3807/4923 done!
# 457/587 DONE
# LibriSpeech/train-clean-100/3807/4955 done!
# 458/587 DONE
# LibriSpeech/train-clean-100/8088/284756 done!
# 459/587 DONE
# LibriSpeech/train-clean-100/4441/76262 done!
# 460/587 DONE
# LibriSpeech/train-clean-100/4441/76263 done!
# 461/587 DONE
# LibriSpeech/train-clean-100/4441/76250 done!
# 462/587 DONE
# LibriSpeech/train-clean-100/3664/11714 done!
# 463/587 DONE
# LibriSpeech/train-clean-100/3664/178355 done!
# 464/587 DONE
# LibriSpeech/train-clean-100/3664/178366 done!
# 465/587 DONE
# LibriSpeech/train-clean-100/2910/131096 done!
# 466/587 DONE
# LibriSpeech/train-clean-100/4680/16042 done!
# 467/587 DONE
# LibriSpeech/train-clean-100/4680/16026 done!
# 468/587 DONE
# LibriSpeech/train-clean-100/4680/16041 done!
# 469/587 DONE
# LibriSpeech/train-clean-100/5104/33407 done!
# 470/587 DONE
# LibriSpeech/train-clean-100/5104/33406 done!
# 471/587 DONE
# LibriSpeech/train-clean-100/7402/59171 done!
# 472/587 DONE
# LibriSpeech/train-clean-100/7402/90848 done!
# 473/587 DONE
# LibriSpeech/train-clean-100/2514/149482 done!
# 474/587 DONE
# LibriSpeech/train-clean-100/7059/88364 done!
# 475/587 DONE
# LibriSpeech/train-clean-100/7059/77897 done!
# 476/587 DONE
# LibriSpeech/train-clean-100/7059/77900 done!
# 477/587 DONE
# LibriSpeech/train-clean-100/696/93314 done!
# 478/587 DONE
# LibriSpeech/train-clean-100/696/92939 done!
# 479/587 DONE
# LibriSpeech/train-clean-100/6147/34605 done!
# 480/587 DONE
# LibriSpeech/train-clean-100/6147/34606 done!
# 481/587 DONE
# LibriSpeech/train-clean-100/6147/34607 done!
# 482/587 DONE
# LibriSpeech/train-clean-100/3607/135982 done!
# 483/587 DONE
# LibriSpeech/train-clean-100/3607/29116 done!
# 484/587 DONE
# LibriSpeech/train-clean-100/201/127786 done!
# 485/587 DONE
# LibriSpeech/train-clean-100/201/122255 done!
# 486/587 DONE
# LibriSpeech/train-clean-100/1502/122619 done!
# 487/587 DONE
# LibriSpeech/train-clean-100/1502/122615 done!
# 488/587 DONE
# LibriSpeech/train-clean-100/5390/30096 done!
# 489/587 DONE
# LibriSpeech/train-clean-100/5390/30102 done!
# 490/587 DONE
# LibriSpeech/train-clean-100/5390/24512 done!
# 491/587 DONE
# LibriSpeech/train-clean-100/2989/138035 done!
# 492/587 DONE
# LibriSpeech/train-clean-100/2989/138028 done!
# 493/587 DONE
# LibriSpeech/train-clean-100/839/130898 done!
# 494/587 DONE
# LibriSpeech/train-clean-100/1737/142396 done!
# 495/587 DONE
# LibriSpeech/train-clean-100/1737/146161 done!
# 496/587 DONE
# LibriSpeech/train-clean-100/1737/142397 done!
# 497/587 DONE
# LibriSpeech/train-clean-100/1737/148989 done!
# 498/587 DONE
# LibriSpeech/train-clean-100/2911/12359 done!
# 499/587 DONE
# LibriSpeech/train-clean-100/2911/15084 done!
# 500/587 DONE
# LibriSpeech/train-clean-100/2911/15045 done!
# 501/587 DONE
# LibriSpeech/train-clean-100/2911/7601 done!
# 502/587 DONE
# LibriSpeech/train-clean-100/5561/41616 done!
# 503/587 DONE
# LibriSpeech/train-clean-100/5561/39621 done!
# 504/587 DONE
# LibriSpeech/train-clean-100/5561/41615 done!
# 505/587 DONE
# LibriSpeech/train-clean-100/3830/12531 done!
# 506/587 DONE
# LibriSpeech/train-clean-100/3830/12530 done!
# 507/587 DONE
# LibriSpeech/train-clean-100/3830/12535 done!
# 508/587 DONE
# LibriSpeech/train-clean-100/3830/12529 done!
# 509/587 DONE
# LibriSpeech/train-clean-100/7800/283478 done!
# 510/587 DONE
# LibriSpeech/train-clean-100/7800/283492 done!
# 511/587 DONE
# LibriSpeech/train-clean-100/7800/283493 done!
# 512/587 DONE
# LibriSpeech/train-clean-100/5339/14134 done!
# 513/587 DONE
# LibriSpeech/train-clean-100/5339/14133 done!
# 514/587 DONE
# LibriSpeech/train-clean-100/403/216 done!
# 515/587 DONE
# LibriSpeech/train-clean-100/403/128339 done!
# 516/587 DONE
# LibriSpeech/train-clean-100/403/126855 done!
# 517/587 DONE
# LibriSpeech/train-clean-100/8419/286667 done!
# 518/587 DONE
# LibriSpeech/train-clean-100/8419/286676 done!
# 519/587 DONE
# LibriSpeech/train-clean-100/8419/293473 done!
# 520/587 DONE
# LibriSpeech/train-clean-100/8419/293469 done!
# 521/587 DONE
# LibriSpeech/train-clean-100/1594/135914 done!
# 522/587 DONE
# LibriSpeech/train-clean-100/8108/280359 done!
# 523/587 DONE
# LibriSpeech/train-clean-100/8108/274318 done!
# 524/587 DONE
# LibriSpeech/train-clean-100/8108/280354 done!
# 525/587 DONE
# LibriSpeech/train-clean-100/911/130578 done!
# 526/587 DONE
# LibriSpeech/train-clean-100/911/128684 done!
# 527/587 DONE
# LibriSpeech/train-clean-100/4160/14187 done!
# 528/587 DONE
# LibriSpeech/train-clean-100/4160/11550 done!
# 529/587 DONE
# LibriSpeech/train-clean-100/4160/11549 done!
# 530/587 DONE
# LibriSpeech/train-clean-100/7178/34644 done!
# 531/587 DONE
# LibriSpeech/train-clean-100/7178/34645 done!
# 532/587 DONE
# LibriSpeech/train-clean-100/83/3054 done!
# 533/587 DONE
# LibriSpeech/train-clean-100/83/11691 done!
# 534/587 DONE
# LibriSpeech/train-clean-100/83/9960 done!
# 535/587 DONE
# LibriSpeech/train-clean-100/1040/133433 done!
# 536/587 DONE
# LibriSpeech/train-clean-100/311/124404 done!
# 537/587 DONE
# LibriSpeech/train-clean-100/3374/298025 done!
# 538/587 DONE
# LibriSpeech/train-clean-100/3374/298032 done!
# 539/587 DONE
# LibriSpeech/train-clean-100/3374/298026 done!
# 540/587 DONE
# LibriSpeech/train-clean-100/4397/15666 done!
# 541/587 DONE
# LibriSpeech/train-clean-100/4397/15668 done!
# 542/587 DONE
# LibriSpeech/train-clean-100/4397/15678 done!
# 543/587 DONE
# LibriSpeech/train-clean-100/6209/34601 done!
# 544/587 DONE
# LibriSpeech/train-clean-100/6209/34600 done!
# 545/587 DONE
# LibriSpeech/train-clean-100/6209/34599 done!
# 546/587 DONE
# LibriSpeech/train-clean-100/3112/9555 done!
# 547/587 DONE
# LibriSpeech/train-clean-100/3112/9554 done!
# 548/587 DONE
# LibriSpeech/train-clean-100/7780/274562 done!
# 549/587 DONE
# LibriSpeech/train-clean-100/2691/156755 done!
# 550/587 DONE
# LibriSpeech/train-clean-100/2691/156750 done!
# 551/587 DONE
# LibriSpeech/train-clean-100/2691/156745 done!
# 552/587 DONE
# LibriSpeech/train-clean-100/6836/61803 done!
# 553/587 DONE
# LibriSpeech/train-clean-100/6836/61804 done!
# 554/587 DONE
# LibriSpeech/train-clean-100/6836/76549 done!
# 555/587 DONE
# LibriSpeech/train-clean-100/7113/86041 done!
# 556/587 DONE
# LibriSpeech/train-clean-100/5688/41232 done!
# 557/587 DONE
# LibriSpeech/train-clean-100/5688/15787 done!
# 558/587 DONE
# LibriSpeech/train-clean-100/374/180298 done!
# 559/587 DONE
# LibriSpeech/train-clean-100/374/180299 done!
# 560/587 DONE
# LibriSpeech/train-clean-100/2002/139469 done!
# 561/587 DONE
# LibriSpeech/train-clean-100/328/129766 done!
# 562/587 DONE
# LibriSpeech/train-clean-100/4362/15663 done!
# 563/587 DONE
# LibriSpeech/train-clean-100/7148/7763 done!
# 564/587 DONE
# LibriSpeech/train-clean-100/7148/82991 done!
# 565/587 DONE
# LibriSpeech/train-clean-100/7148/59157 done!
# 566/587 DONE
# LibriSpeech/train-clean-100/5049/25947 done!
# 567/587 DONE
# LibriSpeech/train-clean-100/125/121124 done!
# 568/587 DONE
# LibriSpeech/train-clean-100/125/121342 done!
# 569/587 DONE
# LibriSpeech/train-clean-100/2092/145709 done!
# 570/587 DONE
# LibriSpeech/train-clean-100/2092/145706 done!
# 571/587 DONE
# LibriSpeech/train-clean-100/40/121026 done!
# 572/587 DONE
# LibriSpeech/train-clean-100/40/222 done!
# 573/587 DONE
# LibriSpeech/train-clean-100/4195/186236 done!
# 574/587 DONE
# LibriSpeech/train-clean-100/4195/186238 done!
# 575/587 DONE
# LibriSpeech/train-clean-100/4195/186237 done!
# 576/587 DONE
# LibriSpeech/train-clean-100/4195/17507 done!
# 577/587 DONE
# LibriSpeech/train-clean-100/78/368 done!
# 578/587 DONE
# LibriSpeech/train-clean-100/78/369 done!
# 579/587 DONE
# LibriSpeech/train-clean-100/1447/17506 done!
# 580/587 DONE
# LibriSpeech/train-clean-100/1447/130552 done!
# 581/587 DONE
# LibriSpeech/train-clean-100/1447/130550 done!
# 582/587 DONE
# LibriSpeech/train-clean-100/1447/130551 done!
# 583/587 DONE
# LibriSpeech/train-clean-100/2836/5354 done!
# 584/587 DONE
# LibriSpeech/train-clean-100/2836/5355 done!
# 585/587 DONE
# LibriSpeech/train-clean-100/5022/29405 done!
# 586/587 DONE
# LibriSpeech/train-clean-100/5022/29411 done!
# 587/587 DONE
